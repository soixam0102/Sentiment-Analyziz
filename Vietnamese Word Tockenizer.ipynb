# %% [markdown]
# # Tóm tắt bài báo A fast and accurate Vietnamese Word Segmenter

# %% [markdown]
# 1. INTRODUCTION

# %% [markdown]
# - Tách từ là một bước quan trọng đầu tiên của quá trình sử lý ngôn ngữ tiếng việt.
#
# - Không giống như tiếng anh, khi mà các từ trong tiếng anh được phân chia với nhau một cách dõ dàng thông qua dấu cách. Đối với tiếng việt có hơn 85% các từ ngữ được cấu thành từ các từ đơn âm tiết.

# %% [markdown]
# - Sử dụng các cộng đồng như toward data science, medium
# - Sử dụng công cụ hugging face cho NLP
# - Học cách sử dụng thành kiếm luôn

# %% [markdown]
# - lưu ý về byteLevel của huggingface trong quá trình tiền sử lý tocken từ. Phobert sử dụng byte level hay gì ?
# - Sử dụng VNCORENLP segmentation : https://github.com/vncorenlp/VnCoreNLP
# - bài báo: https://arxiv.org/pdf/1801.01331.pdf

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - đọc báo về tách từ tiếng việt ở trên z + bear và pho bear
# - https://viblo.asia/p/bert-roberta-phobert-bertweet-ung-dung-state-of-the-art-pre-trained-model-cho-bai-toan-phan-loai-van-ban-4P856PEWZY3
